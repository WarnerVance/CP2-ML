# %%
import pandas as pd
melbourne_data = pd.read_csv('melb_data.csv')
melbourne_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
melbourne_data['Price'] = melbourne_data['Price']*.65
# This changes the price so it becomes to USD

# %%
import seaborn as sns
sns.histplot(melbourne_data['Price'], kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
melbourne_data.YearBuilt.fillna(melbourne_data.YearBuilt.mean(), inplace=True)
melbourne_data.BuildingArea.fillna(melbourne_data.BuildingArea.mean(), inplace=True)
melbourne_data.Car.fillna(melbourne_data.Car.mean(), inplace=True)
# Out:
# /var/folders/fz/ckrqtrgs0zqfznq4jsbhy6bw0000gn/T/ipykernel_33004/1769737327.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   melbourne_data.YearBuilt.fillna(melbourne_data.YearBuilt.mean(), inplace=True)
# /var/folders/fz/ckrqtrgs0zqfznq4jsbhy6bw0000gn/T/ipykernel_33004/1769737327.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
y = melbourne_data.Price
features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude', 'Postcode', 'BuildingArea', 'YearBuilt', "Car", "Distance"]
X = melbourne_data[features]

# %%
melbourne_data.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt           0
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(random_state=1)
dt.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print(dt.predict(X.head()))
y.head()
# Out:
# [ 962000.  672750.  952250.  552500. 1040000.]
# 0     962000.0
# 1     672750.0
# 2     952250.0
# 3     552500.0
# 4    1040000.0
# Name: Price, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
predicted_home_prices = dt.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 268.73128375061367

# %% [markdown]
# In the previous model we trained the data on the data we also tried to predict.

# %%
from sklearn.model_selection import train_test_split
X_train, x_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
dt2 = DecisionTreeRegressor(random_state=1, max_leaf_nodes=469) 
dt2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=469, random_state=1)

# %%
predicted_home_prices2 = dt2.predict(x_test)
mean_absolute_error(y_test, predicted_home_prices2)
# Out:
# 139387.92441222855

# %%
# from sklearn import tree 
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10,8), dpi=500)
# tree.plot_tree(dt2, filled=True)
# # plt.show()

# %%
# We are now gonna compar the diffrent mean absolute errors for different max leaf nodes
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, X_train, x_test, y_train, y_test):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(X_train, y_train)
    preds_val = model.predict(x_test)
    mae = mean_absolute_error(y_test, preds_val)
    return(mae)

# %%
max_my_mae = 0
for max_leaf_nodes in range(480, 2200, 4):
    my_mae = get_mae(max_leaf_nodes, X_train, x_test, y_train, y_test)
    # print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
    if max_my_mae == 0 or my_mae < max_my_mae:
        max_my_mae = my_mae
        best_max_leaf_nodes = max_leaf_nodes
print("Best max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(best_max_leaf_nodes, max_my_mae))
# Out:
# Best max leaf nodes: 488  		 Mean Absolute Error:  139689

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

RandomForestRegressor_model = RandomForestRegressor(random_state=1)
RandomForestRegressor_model.fit(X_train, y_train)
preds = RandomForestRegressor_model.predict(x_test)
print(mean_absolute_error(y_test, preds))
# Out:
# 108752.86085299637
