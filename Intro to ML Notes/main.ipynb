# %%
import pandas as pd

# %%
df = pd.read_csv('framingham.csv')
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
# Data exploration 

# Max and min of each column

# Gender distribution

# Average Age

# Histogram of number of cigarettes smoked per day
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
# 4238       67.0     72.0           0
# 4239       85.0     80.0           0
#
# [4240 rows x 16 columns]

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# min       0.000000         0.000000      0.000000     0.000000   107.000000
# 25%       0.000000         0.000000      0.000000     0.000000   206.000000
# 50%       0.000000         0.000000      0.000000     0.000000   234.000000
# 75%       0.000000         0.000000      1.000000     0.000000   263.000000
# max       1.000000         1.000000      1.000000     1.000000   696.000000
#
#              sysBP        diaBP          BMI    heartRate      glucose  \
# count  4240.000000  4240.000000  4221.000000  4239.000000  3852.000000
# mean    132.354599    82.897759    25.800801    75.878981    81.963655
# std      22.033300    11.910394     4.079840    12.025348    23.954335
# min      83.500000    48.000000    15.540000    44.000000    40.000000
# 25%     117.000000    75.000000    23.070000    68.000000    71.000000
# 50%     128.000000    82.000000    25.400000    75.000000    78.000000
# 75%     144.000000    90.000000    28.040000    83.000000    87.000000
# max     295.000000   142.500000    56.800000   143.000000   394.000000
#
#         TenYearCHD
# count  4240.000000
# mean      0.151887
# std       0.358953
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
import seaborn as sns 
sns.countplot(df, x = "male")
# Out:
# <Axes: xlabel='male', ylabel='count'>

# %%
sns.histplot(df, x = "cigsPerDay")
# Out:
# <Axes: xlabel='cigsPerDay', ylabel='Count'>

# %%
df['currentSmoker'].value_counts()
# Out:
# currentSmoker
# 0    2145
# 1    2095
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Separate the feature and target

# %%
X = df.drop('TenYearCHD', axis = 1)
y = df['TenYearCHD']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=413) # The random state is set to 413 to ensure reproducibility
X_train
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 2436     0   50        2.0              1         9.0     0.0
# 2181     0   56        1.0              1         9.0     NaN
# 362      0   48        4.0              0         0.0     0.0
# 1524     0   37        4.0              0         0.0     0.0
# 1174     0   62        2.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 979      0   64        1.0              0         0.0     0.0
# 952      1   66        1.0              1        30.0     0.0
# 3726     0   56        3.0              1         1.0     0.0
# 568      0   34        2.0              0         0.0     0.0
# 2119     1   54        3.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 2436                0             1         0    161.0  145.0   89.0  20.30
# 2181                0             1         0    320.0  142.0   84.0  27.90
# 362                 0             0         0    200.0  118.0   78.0  24.53
# 1524                0             1         0    240.0  125.0   96.0  27.17
# 1174                0             1         0    304.0  165.0   91.0  26.97
# ...               ...           ...       ...      ...    ...    ...    ...
# 979                 0             1         0    239.0  132.0   75.0  20.67
# 952                 0             0         1    234.0  114.5   62.5  28.62
# 3726                0             1         0    260.0  120.0   84.0  36.18
# 568                 0             0         0    189.0  108.0   66.0  20.81
# 2119                0             1         0    258.0  146.0   98.5  26.05
#
#       heartRate  glucose
# 2436       66.0     81.0
# 2181       74.0     95.0
# 362        63.0     98.0
# 1524       75.0      NaN
# 1174       80.0     81.0
# ...         ...      ...
# 979        86.0     80.0
# 952        75.0    216.0
# 3726       80.0     76.0
# 568        78.0     88.0
# 2119       60.0     68.0
#
# [3392 rows x 15 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
importance = dt.feature_importances_
for i, j in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i, j))
# Out:
# Feature: 0, Score: 0.02153
# Feature: 1, Score: 0.11869
# Feature: 2, Score: 0.05789
# Feature: 3, Score: 0.00421
# Feature: 4, Score: 0.04315
# Feature: 5, Score: 0.00471
# Feature: 6, Score: 0.00270
# Feature: 7, Score: 0.00499
# Feature: 8, Score: 0.00175
# Feature: 9, Score: 0.16088
# Feature: 10, Score: 0.13473
# Feature: 11, Score: 0.10368
# Feature: 12, Score: 0.14301
# Feature: 13, Score: 0.08165
# Feature: 14, Score: 0.11643
