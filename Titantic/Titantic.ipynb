# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train[train["Sex"] == 'female'].plot(kind='hist', column = "Age", by = 'Survived', ylim=(0,100))
# Out:
# array([<Axes: title={'center': '0'}, ylabel='Frequency'>,
#        <Axes: title={'center': '1'}, ylabel='Frequency'>], dtype=object)

# %%
train[train["Sex"] == 'male'].plot(kind='hist', column = "Age", by = 'Survived', ylim=(0,100))
# Out:
# array([<Axes: title={'center': '0'}, ylabel='Frequency'>,
#        <Axes: title={'center': '1'}, ylabel='Frequency'>], dtype=object)

# %%
# I've been assigned SibSp to work on. Our goal my goal is to see wether it matters in terms of survival rate
train.plot(kind='hist', column = "SibSp", by = 'Survived', ylim=(0,400))
# It does matter a little bit but people people with 1 sibling or spouse have a higher survival rate.
# Out:
# array([<Axes: title={'center': '0'}, ylabel='Frequency'>,
#        <Axes: title={'center': '1'}, ylabel='Frequency'>], dtype=object)
